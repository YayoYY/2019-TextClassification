# %%
'''
feature_engineering.py
'''
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, f_classif, chi2
import warnings
warnings.filterwarnings('ignore')

labels = ['交通肇事', '信用卡诈骗' ,'危险驾驶', '受贿' ,'合同诈骗', '妨害公务', '容留他人吸毒' ,'寻衅滋事','开设赌场',
 '引诱、容留、介绍卖淫', '抢劫', '抢夺', '掩饰、隐瞒犯罪所得、犯罪所得收益', '故意伤害', '故意杀人', '故意毁坏财物', '敲诈勒索',
 '滥伐林木' ,'生产、销售假药', '盗窃', '组织、强迫、引诱、容留、介绍卖淫', '职务侵占','诈骗' ,'贪污', '赌博',
 '走私、贩卖、运输、制造毒品' ,'过失致人死亡' ,'非法拘禁', '非法持有、私藏枪支、弹药' ,'非法持有毒品']

def vsm_tfidf(max_features=5000, max_df=0.8, analyzer='word', ngram_range=(1,1)):
    print('>>> reading...')
    train = pd.read_csv('../data/train.csv')
    test = pd.read_csv('../data/test.csv')
    print('train size:', train.shape)
    print('test size:', test.shape)

    print('>>> tf idf featuring...')
    if analyzer == 'char':
        train.words = train.words.apply(lambda x: x.replace(' ', ''))
        test.words = test.words.apply(lambda x: x.replace(' ', ''))
    tfidfer = TfidfVectorizer(max_features=max_features, max_df=max_df, analyzer=analyzer, ngram_range=ngram_range)
    tfidfer.fit(train.words)
    feature_names = tfidfer.get_feature_names()
    tfidf = tfidfer.transform(train.words)
    train_feature = tfidf.toarray()
    tfidf = tfidfer.transform(test.words)
    test_feature = tfidf.toarray()
    print('tfidfer feature:', feature_names[:20])
    print('train feature shape:', train_feature.shape)
    print('test feature shape:', test_feature.shape)
    
    print('>>> feature selecting...')
    selector = SelectKBest(chi2, k=500)
    train_feature = selector.fit_transform(train_feature, train['accusation'])
    selected_features = selector.inverse_transform(train_feature)
    selected_columns = np.where(~(selector.inverse_transform(train_feature) == 0).all(axis=0))[0]
    test_feature = test_feature[:, selected_columns]
    print('selected feature:', [feature_names[i] for i in selected_columns])
    print('train feature selected shape:', train_feature.shape)
    print('test feature selected shape:', test_feature.shape)
    
    return train, test, train_feature, test_feature, feature_names, labels

# %%
'''
classifiers.py
'''
import functools, time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
import lightgbm as lgb

def logtime(func):
    @functools.wraps(func)
    def wrapper(*args, **kw):
        time1 = time.time()
        result = func(*args, **kw)
        time2 = time.time()
        print(func.__name__, 'time cost:', round(time2-time1, 4), 's')
        return result
    return wrapper

class Classifier():
    def __init__(self):
        self.model = None
    
    @logtime
    def train(self, X, y):
        self.model.fit(X, y)
        
    @logtime
    def predict(self, X):
        return self.model.predict_proba(X)

class LR(Classifier):
    name = 'Logistic Regression'
    def __init__(self, C=1.0, penalty='l2', solver='saga'):
        self.model = OneVsRestClassifier(LogisticRegression(solver=solver, 
                                                            C=C, 
                                                            penalty=penalty,
                                                            n_jobs=-1))
        
class SVM(Classifier):
    name = 'SVM'
    def __init__(self, C=1.0, kernel='rbf', probability=True):
        self.model = OneVsRestClassifier(SVC(C=C,
                                             kernel=kernel, 
                                             probability=probability))
        
class KNN(Classifier):
    name = 'KNN'
    def __init__(self, n_neighbors=20, metric='euclidean', algorithm='ball_tree'):
        self.model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=n_neighbors, 
                                                              metric=metric,
                                                              algorithm=algorithm,
                                                              n_jobs=-1)) 
class DT(Classifier):
    name = 'Decision Tree'
    def __init__(self):
        self.model = OneVsRestClassifier(DecisionTreeClassifier(max_depth=3,
                                                                min_samples_leaf=5))
        
class NB(Classifier):
    name = 'NN'
    def __init__(self):
        self.model = OneVsRestClassifier(GaussianNB())
        
class LGB(Classifier):
    name = 'LGB'
    def __init__(self):
        self.model = OneVsRestClassifier(lgb.LGBMClassifier(num_leaves=2**5,
                                                            reg_alpha=0.25,
                                                            reg_lambda=0.25,
                                                            max_depth=-1, 
                                                            learning_rate=0.05,
                                                            min_child_sample=5,
                                                            n_estimators=2000,
                                                            subsample=0.9,
                                                            colsample_bytree=0.7, 
                                                            objective='binary',
                                                            silent=200))

# %%
'''
ml_methods_exp.py
'''
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, classification_report
# from classifiers import *
# from feature_engineering import *
import warnings
warnings.filterwarnings('ignore')

avgf1_scorer = lambda x,y: (f1_score(x, y, average='macro') + f1_score(x, y, average='micro')) / 2

def experiments(analyzer='word', ngram_range=(1,1)):
    print('==================================')
    print('analyzer=%s, ngram_range=%s' %(analyzer, str(ngram_range)))
    print('==================================')
    
    train, test, train_feature, test_feature, feature_names, labels = vsm_tfidf(analyzer=analyzer, ngram_range=ngram_range)

    classifiers = [LR(), SVM(), KNN(), NB(), DT(), LGB()]
    for model in classifiers:
        print('-----------------------%s-----------------------' % model.name)
        print('>>> training...')
        model.train(train_feature, train[list(map(str, range(30)))].values)

        print('>>> predicting...')
        pred_y_prob = model.predict(test_feature)
        up75 = np.percentile(test[list(map(str, range(30)))].values.sum(axis=0), q=75)
        mask = test[list(map(str, range(30)))].values.sum(axis=0) > up75
        big_class_idx, small_class_idx = np.where(mask)[0], np.where(~mask)[0]
        pred_y_prob_mod = pred_y_prob.copy()
        pred_y_prob_mod[:, big_class_idx] = (pred_y_prob[:, big_class_idx] >= 00.32).astype(int)
        pred_y_prob_mod[:, small_class_idx] = (pred_y_prob[:, small_class_idx] >= 0.18).astype(int)

        print('>>> evaluating...')
        report = classification_report(test[list(map(str, range(30)))].values, pred_y_prob_mod, target_names=[x[:3]+'..\t' for x in labels])
        print(report)
        score = avgf1_scorer(test[list(map(str, range(30)))].values, pred_y_prob_mod)
        print('avg f1 score:', score)

if __name__ == '__main__':
    experiments(analyzer='word', ngram_range=(1,1))
    experiments(analyzer='char', ngram_range=(2,2))
# Out:
# ==================================
# analyzer=word, ngram_range=(1, 1)
# ==================================
# >>> reading...
# train size: (32171, 36)
# test size: (3575, 36)
# >>> tf idf featuring...
# tfidfer feature: ['一万元', '一个月', '一串', '一事', '一人', '一件', '一份', '一伙', '一刀', '一副', '一包', '一区', '一双', '一只', '一台', '一号', '一同', '一名', '一块', '一处']
# train feature shape: (32171, 5000)
# test feature shape: (3575, 5000)
# >>> feature selecting...
# selected feature: ['一包', '一小包', '一张', '一支', '一级', '一部', '万元', '万州区', '万某', '三个', '上报', '不备', '不锈钢', '业务员', '两支', '中信银行', '中国农业银行', '中国工商银行', '中国建设银行', '中国银行', '丹阳市', '为名', '主任', '主管部门', '之机', '乙醇', '书记', '争吵', '事故', '事故现场', '二七区', '二级', '二轮', '交往', '交易', '交通事故', '交通警察', '交通银行', '产品', '亲属', '人体', '人员', '人民币', '人民政府', '人身自由', '介绍', '代某', '以能', '价值', '价格', '价钱', '任意', '任职', '伟哥', '传销', '伤情', '伪造', '位于', '低于', '使用暴力', '侵占', '侵吞', '便利', '俗称', '保健品', '信任', '信函', '信用', '信用卡', '修路', '借款', '债务', '假药', '偿还', '催收', '催缴', '党支部', '公司', '公款', '六合彩', '关照', '内容', '冒用', '农用车', '农药', '冰毒', '净重', '击发', '分行', '分许', '利息', '利用', '利益', '制式', '剥夺', '办理', '动力', '劫取', '劫得', '化名', '协警', '卖淫', '卖淫女', '卖淫嫖娼', '卖淫罪', '南边', '占为己有', '卡号', '危房改造', '原木', '原油', '厮打', '参赌', '反抗', '发卡', '发卡行', '发射', '发放', '发泄', '发生', '发生争执', '发还', '取现', '受伤', '受贿', '口角', '可疑', '司法鉴定', '合同', '名义', '含量', '吸引', '吸毒', '吸食', '吸食毒品', '呼气', '固镇县', '国家机关', '场所', '复方', '外围', '大队', '头薪', '头部', '夺取', '套取', '好处费', '妇女', '威胁', '嫖娼', '嫖客', '嫖资', '子弹', '宜春市', '客户', '家中', '家属', '容留', '寻衅滋事', '射钉', '射钉枪', '小包', '小型', '尸体', '尿液', '履行合同', '山场', '山林', '工程', '巩义市', '广发', '庐江县', '店员', '废铁', '开设', '弹丸', '弹药', '强行', '归还', '形式', '征地', '得罪', '德国', '性关系', '恶意透支', '情节恶劣', '感谢', '成人', '成分', '截止', '所得', '手机', '手枪', '扑克牌', '打伤', '打猎', '打砸', '执勤', '执法', '执法人员', '执行公务', '批准', '承担', '投注', '投注单', '抗拒', '抢劫', '抢夺', '抢救无效', '抢走', '抵押', '抽头', '抽水', '抽血', '担任', '拆迁', '拖欠', '拘禁', '拨付', '持刀', '持卡', '持有', '持枪', '挡风玻璃', '捕鱼机', '损伤', '损毁', '据为己有', '掩饰', '摆设', '摩托车', '擅自', '支行', '收取', '收受', '收购', '改制', '改装', '放在', '故意伤害', '数刀', '数罪', '数罪并罚', '数量', '敲诈', '敲诈勒索', '方向', '无故', '无证', '明知', '晶体', '暴力', '有限公司', '木材', '未办理', '未经', '本息', '本金', '机动车', '杀人', '杀伤力', '杉木', '杨树', '林业', '林业局', '林地', '林木', '枪弹', '枪支', '枪支罪', '某龙', '查获', '检出', '检测', '检验', '棋牌室', '森林', '森林法', '欠款', '死亡', '殴打', '毁坏', '每盒', '毒品', '毒资', '民警', '气枪', '氯胺酮', '水泥厂', '永嘉县', '汇款', '沧州市', '油锯', '法医鉴定', '活动', '活立木', '派出所', '浓度', '海洛因', '消费', '渔利', '游戏机', '滞纳金', '滥伐', '滥伐林木', '濮阳市', '火药', '火药枪', '片剂', '牟利', '猎枪', '现金', '琐事', '生产', '生命', '用品店', '甲基苯丙胺', '申办', '申请', '申领', '电子游戏', '电子游戏机', '疏忽大意', '疑似', '白色', '监督', '盗窃', '盗走', '相撞', '相识', '真相', '砂枪', '砍伐', '砍伤', '砸坏', '碰撞', '科学', '科尔沁区', '租住', '租赁', '租车', '称量', '程度', '窃取', '窃得', '窝点', '立方米', '立木', '签订', '管理法', '粮食', '系以', '索取', '索要', '纠纷', '组织', '经查', '经营', '给予', '缴获', '网站', '美国', '职务', '聚众赌博', '肇事', '股份', '胶囊', '脖子', '自制', '致一人', '致人', '苹果', '荣县', '药丸', '药品', '药品监督管理局', '莲都区', '获利', '营利', '蓄积', '蓄积量', '虚假', '虚报', '虚构', '虫草', '血样', '血液', '行人', '行驶', '补偿款', '补助', '补助款', '补贴', '补贴款', '被害人', '被盗', '被迫', '要挟', '解救', '警车', '认定', '认定书', '许可证', '论处', '设置', '诈骗', '诈骗罪', '该卡', '该车', '谅解', '谋取', '谎称', '负责', '财政', '责任', '货款', '货车', '贩卖', '贩卖毒品', '贪污', '购买', '购进', '贷记卡', '贿赂', '贿赂款', '赃物', '资金', '赌具', '赌博', '赌博机', '赌场', '赌客', '赌资', '赔偿', '超过', '路段', '身上', '身为', '身体', '车辆', '轻伤', '轻微伤', '轿车', '较大', '辅警', '辱骂', '近亲属', '还款', '还清', '进口', '违反', '追回', '追逐', '退耕还林', '送给', '逃逸', '透支', '通辽市', '逼迫', '逾期', '道路', '道路交通', '遵义市', '邬某', '配合', '酒后', '酒精', '醉酒', '采伐', '采购', '重伤', '重型', '钱包', '银行', '销售', '阜南县', '阳性', '阻碍', '随意', '隐瞒', '雇请', '非法', '非法拘禁', '面积', '面部', '项目', '颅脑', '额度', '食品', '饮酒', '马尾松', '驾驶', '骗取', '骗得', '骗走', '骨折', '鸟铳', '麻古', '麻将', '麻将桌']
# train feature selected shape: (32171, 500)
# test feature selected shape: (3575, 500)
# -----------------------Logistic Regression-----------------------
# >>> training...
# train time cost: 220.9116 s
# >>> predicting...
# predict time cost: 0.186 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.91      0.97      0.94       367
#      信用卡..	       0.91      0.85      0.88        59
#      危险驾..	       0.98      0.98      0.98       768
#       受贿..	       0.92      0.79      0.85        28
#      合同诈..	       0.40      0.27      0.32        15
#      妨害公..	       0.97      0.73      0.83        41
#      容留他..	       0.95      0.91      0.93       154
#      寻衅滋..	       0.78      0.24      0.37        88
#      开设赌..	       0.68      0.73      0.70        26
#      引诱、..	       1.00      0.81      0.89        21
#       抢劫..	       0.93      0.60      0.73        65
#       抢夺..	       0.83      0.42      0.56        24
#      掩饰、..	       0.90      0.75      0.82        24
#      故意伤..	       0.91      0.97      0.94       467
#      故意杀..	       0.67      0.10      0.17        20
#      故意毁..	       0.62      0.29      0.40        17
#      敲诈勒..	       1.00      0.06      0.12        16
#      滥伐林..	       1.00      0.96      0.98        25
#      生产、..	       1.00      0.94      0.97        16
#       盗窃..	       0.93      0.98      0.96       759
#      组织、..	       1.00      0.81      0.89        21
#      职务侵..	       0.85      0.55      0.67        20
#       诈骗..	       0.93      0.66      0.78       122
#       贪污..	       0.53      0.53      0.53        15
#       赌博..	       0.86      0.72      0.78        25
#      走私、..	       0.91      0.93      0.92       300
#      过失致..	       1.00      0.16      0.27        19
#      非法拘..	       1.00      0.20      0.33        20
#      非法持..	       1.00      0.93      0.96        42
#      非法持..	       0.47      0.62      0.53        45
#
# avg / total       0.92      0.88      0.89      3629
#
# avg f1 score: 0.8016114558240257
# -----------------------SVM-----------------------
# >>> training...
# train time cost: 15434.0258 s
# >>> predicting...
# predict time cost: 217.8805 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.83      0.98      0.90       367
#      信用卡..	       0.91      0.85      0.88        59
#      危险驾..	       0.96      0.98      0.97       768
#       受贿..	       0.85      0.82      0.84        28
#      合同诈..	       0.59      0.67      0.62        15
#      妨害公..	       0.78      0.85      0.81        41
#      容留他..	       0.88      0.95      0.91       154
#      寻衅滋..	       0.78      0.35      0.48        88
#      开设赌..	       0.64      0.81      0.71        26
#      引诱、..	       1.00      0.95      0.98        21
#       抢劫..	       0.88      0.82      0.85        65
#       抢夺..	       0.89      0.71      0.79        24
#      掩饰、..	       0.77      0.96      0.85        24
#      故意伤..	       0.86      0.97      0.91       467
#      故意杀..	       0.64      0.35      0.45        20
#      故意毁..	       0.73      0.65      0.69        17
#      敲诈勒..	       0.68      0.81      0.74        16
#      滥伐林..	       1.00      1.00      1.00        25
#      生产、..	       1.00      0.94      0.97        16
#       盗窃..	       0.86      0.97      0.91       759
#      组织、..	       1.00      0.95      0.98        21
#      职务侵..	       0.87      0.65      0.74        20
#       诈骗..	       0.86      0.71      0.78       122
#       贪污..	       0.71      0.80      0.75        15
#       赌博..	       0.81      0.68      0.74        25
#      走私、..	       0.86      0.95      0.91       300
#      过失致..	       0.54      0.79      0.64        19
#      非法拘..	       0.93      0.70      0.80        20
#      非法持..	       0.98      0.95      0.96        42
#      非法持..	       0.52      0.71      0.60        45
#
# avg / total       0.87      0.92      0.89      3629
#
# avg f1 score: 0.8489140094912659
# -----------------------KNN-----------------------
# >>> training...
# train time cost: 361.3657 s
# >>> predicting...
# predict time cost: 662.2899 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.95      0.96      0.96       367
#      信用卡..	       0.87      0.88      0.87        59
#      危险驾..	       0.98      0.98      0.98       768
#       受贿..	       0.96      0.79      0.86        28
#      合同诈..	       0.67      0.40      0.50        15
#      妨害公..	       1.00      0.73      0.85        41
#      容留他..	       0.95      0.94      0.94       154
#      寻衅滋..	       0.65      0.35      0.46        88
#      开设赌..	       0.57      0.92      0.71        26
#      引诱、..	       1.00      1.00      1.00        21
#       抢劫..	       0.92      0.68      0.78        65
#       抢夺..	       0.63      0.50      0.56        24
#      掩饰、..	       0.85      0.71      0.77        24
#      故意伤..	       0.87      0.98      0.92       467
#      故意杀..	       0.50      0.50      0.50        20
#      故意毁..	       0.42      0.59      0.49        17
#      敲诈勒..	       0.59      0.62      0.61        16
#      滥伐林..	       1.00      0.96      0.98        25
#      生产、..	       1.00      0.94      0.97        16
#       盗窃..	       0.81      0.99      0.89       759
#      组织、..	       1.00      1.00      1.00        21
#      职务侵..	       0.82      0.70      0.76        20
#       诈骗..	       0.83      0.70      0.76       122
#       贪污..	       0.60      0.60      0.60        15
#       赌博..	       0.67      0.80      0.73        25
#      走私、..	       0.87      0.98      0.92       300
#      过失致..	       0.50      0.58      0.54        19
#      非法拘..	       0.89      0.40      0.55        20
#      非法持..	       1.00      0.93      0.96        42
#      非法持..	       0.45      0.76      0.57        45
#
# avg / total       0.87      0.91      0.89      3629
#
# avg f1 score: 0.8280633776365496
# -----------------------NN-----------------------
# >>> training...
# train time cost: 31.7358 s
# >>> predicting...
# predict time cost: 2.6512 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.30      0.97      0.46       367
#      信用卡..	       0.12      0.90      0.21        59
#      危险驾..	       0.51      0.99      0.67       768
#       受贿..	       0.20      0.86      0.33        28
#      合同诈..	       0.03      0.67      0.06        15
#      妨害公..	       0.02      0.93      0.04        41
#      容留他..	       0.36      0.99      0.52       154
#      寻衅滋..	       0.07      0.89      0.13        88
#      开设赌..	       0.12      0.92      0.21        26
#      引诱、..	       0.20      0.81      0.31        21
#       抢劫..	       0.05      0.94      0.10        65
#       抢夺..	       0.06      0.83      0.12        24
#      掩饰、..	       0.02      0.88      0.04        24
#      故意伤..	       0.53      0.98      0.69       467
#      故意杀..	       0.04      0.75      0.07        20
#      故意毁..	       0.03      0.76      0.06        17
#      敲诈勒..	       0.02      0.75      0.05        16
#      滥伐林..	       0.26      1.00      0.41        25
#      生产、..	       0.20      0.75      0.32        16
#       盗窃..	       0.85      0.98      0.91       759
#      组织、..	       0.20      0.81      0.31        21
#      职务侵..	       0.04      0.90      0.07        20
#       诈骗..	       0.13      0.93      0.23       122
#       贪污..	       0.19      0.60      0.29        15
#       赌博..	       0.31      0.92      0.46        25
#      走私、..	       0.50      0.97      0.66       300
#      过失致..	       0.02      0.74      0.03        19
#      非法拘..	       0.02      0.75      0.04        20
#      非法持..	       0.06      0.93      0.11        42
#      非法持..	       0.08      0.87      0.15        45
#
# avg / total       0.46      0.96      0.58      3629
#
# avg f1 score: 0.29730634465166217
# -----------------------Decision Tree-----------------------
# >>> training...
# train time cost: 19.2371 s
# >>> predicting...
# predict time cost: 0.411 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.97      0.95      0.96       367
#      信用卡..	       0.88      0.85      0.86        59
#      危险驾..	       0.99      0.97      0.98       768
#       受贿..	       0.74      0.82      0.78        28
#      合同诈..	       0.57      0.80      0.67        15
#      妨害公..	       0.66      0.56      0.61        41
#      容留他..	       0.88      0.93      0.90       154
#      寻衅滋..	       0.86      0.34      0.49        88
#      开设赌..	       0.41      0.88      0.56        26
#      引诱、..	       1.00      0.95      0.98        21
#       抢劫..	       0.82      0.63      0.71        65
#       抢夺..	       0.85      0.71      0.77        24
#      掩饰、..	       0.67      0.67      0.67        24
#      故意伤..	       0.91      0.96      0.93       467
#      故意杀..	       0.75      0.30      0.43        20
#      故意毁..	       0.42      0.59      0.49        17
#      敲诈勒..	       0.91      0.62      0.74        16
#      滥伐林..	       0.93      1.00      0.96        25
#      生产、..	       0.94      1.00      0.97        16
#       盗窃..	       0.85      0.90      0.87       759
#      组织、..	       1.00      1.00      1.00        21
#      职务侵..	       0.87      0.65      0.74        20
#       诈骗..	       0.83      0.77      0.80       122
#       贪污..	       0.64      0.60      0.62        15
#       赌博..	       0.56      0.60      0.58        25
#      走私、..	       0.85      0.96      0.90       300
#      过失致..	       0.29      0.79      0.42        19
#      非法拘..	       0.92      0.55      0.69        20
#      非法持..	       0.98      0.95      0.96        42
#      非法持..	       0.87      0.29      0.43        45
#
# avg / total       0.89      0.89      0.88      3629
#
# avg f1 score: 0.8148516181511344
# -----------------------LGB-----------------------
# >>> training...
# train time cost: 177.8342 s
# >>> predicting...
# predict time cost: 2.1941 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.98      0.98      0.98       367
#      信用卡..	       0.90      0.88      0.89        59
#      危险驾..	       1.00      0.99      0.99       768
#       受贿..	       1.00      0.86      0.92        28
#      合同诈..	       0.69      0.60      0.64        15
#      妨害公..	       0.89      0.83      0.86        41
#      容留他..	       0.97      0.98      0.98       154
#      寻衅滋..	       0.75      0.52      0.62        88
#      开设赌..	       0.76      1.00      0.87        26
#      引诱、..	       1.00      0.95      0.98        21
#       抢劫..	       0.90      0.82      0.85        65
#       抢夺..	       0.85      0.71      0.77        24
#      掩饰、..	       0.92      0.96      0.94        24
#      故意伤..	       0.93      0.99      0.96       467
#      故意杀..	       0.67      0.40      0.50        20
#      故意毁..	       0.54      0.76      0.63        17
#      敲诈勒..	       0.64      0.88      0.74        16
#      滥伐林..	       1.00      1.00      1.00        25
#      生产、..	       1.00      1.00      1.00        16
#       盗窃..	       0.96      0.99      0.97       759
#      组织、..	       1.00      0.95      0.98        21
#      职务侵..	       0.88      0.70      0.78        20
#       诈骗..	       0.91      0.85      0.88       122
#       贪污..	       0.72      0.87      0.79        15
#       赌博..	       0.81      0.88      0.85        25
#      走私、..	       0.94      0.97      0.96       300
#      过失致..	       0.52      0.63      0.57        19
#      非法拘..	       0.71      0.75      0.73        20
#      非法持..	       0.98      0.95      0.96        42
#      非法持..	       0.67      0.78      0.72        45
#
# avg / total       0.94      0.95      0.94      3629
#
# avg f1 score: 0.8924394231951167
# ==================================
# analyzer=char, ngram_range=(2, 2)
# ==================================
# >>> reading...
# train size: (32171, 36)
# test size: (3575, 36)
# >>> tf idf featuring...
# 0        公诉机关指控年月日时许被告人魏某本市渭滨区中滩路市场被害人谭市场挑拣红薯不备之机盗走裤子右口...
# 1        山东省平度市人民检察院指控被告人李某甲本村村民李某戊因多年前村内安装电线杆一事积怨年月日时任...
# 2        公诉机关指控年月被告人叶两次上海市金山区枫泾镇兴塔村光荣号实施盗窃事实年月日时许被告人叶地点...
# 3        公诉机关指控年年初月份被告人姚某甲驾驶摩托三轮车携带铁鞋老虎钳工具两次峄城区峨山镇周官庄村东...
# 4        公诉机关指控年月日时许被告人杨某甲武陟县乔庙乡杜村村民张某甲家无人之际家盗走两盒红旗渠牌香烟...
# 32165    公诉机关指派公诉人杨出庭指控年月日时分许告人罗某杭州市城区建国北路号星嘉苑门口窃得被害人尹某...
# 32166    威海经济技术开发区人民检察院指控年月日至月日间被告人李某王某利用工作便利无人之机采用吸金纸吸...
# 32167    审理查明年月日时许被告人孙驾驶苏号轿车高淳县宁高公路由东向西行驶至淳溪镇镇兴路延伸线路口处右...
# 32168    江油市人民检察院指控年月日下午时许被告人高某江油市长钢南二区菜市场盗窃被害人杨一辆价值元灰色...
# 32169    扎赉特旗人民检察院指控年月日时分许被告人代某醉酒无证驾驶号牌农用四轮拖拉机阿拉达尔图苏木发现...
# 32170    湖南省宜章县人民检察院指控年月日上午时许被告人蒋某黄黄某甲李判刑租挖机及货车宜章县梅田镇好运...
# Name: words, Length: 32171, dtype: object
# tfidfer feature: ['.万', '.上', '.元', '.克', '.公', '.属', '.年', '.毫', '.立', '.系', '.被', '.醉', '一个', '一事', '一人', '一件', '一份', '一包', '一医', '一只']
# train feature shape: (32171, 5000)
# test feature shape: (3575, 5000)
# >>> feature selecting...
# selected feature: ['.万', '.元', '.克', '.立', '一包', '一小', '一张', '一支', '一部', '万元', '万某', '不备', '丙胺', '业务', '业局', '业银', '中乙', '中信', '中国', '中容', '中酒', '丹阳', '为己', '主任', '之机', '乙醇', '书记', '争吵', '争执', '事故', '二级', '二轮', '亡交', '交易', '交警', '交通', '产品', '亲属', '人代', '人吸', '人员', '人死', '人轻', '人近', '介绍', '代某', '价值', '价格', '份有', '伐林', '伐许', '众赌', '伤二', '伤力', '伤害', '伤情', '伤死', '伤程', '伤轻', '伤鉴', '伪造', '似毒', '似物', '体损', '体致', '供赌', '便利', '俗称', '保健', '信任', '信用', '信银', '借款', '债务', '值人', '值元', '假药', '偿还', '催收', '元价', '克检', '克毒', '克甲', '公务', '公司', '六合', '内容', '冰毒', '净重', '出乙', '出所', '出甲', '分行', '利人', '利息', '利用', '利益', '利目', '办理', '务便', '动力', '动车', '勤民', '包净', '包毒', '医鉴', '卖吸', '卖毒', '卖淫', '博抽', '博机', '占为', '卡一', '卡卡', '卡号', '卡透', '卡银', '原油', '厮打', '参赌', '发卡', '发射', '发生', '发还', '取利', '取被', '口角', '可疑', '可证', '号信', '号小', '合同', '合彩', '名义', '后驾', '含量', '吸方', '吸毒', '吸食', '品冰', '品可', '品店', '品检', '品海', '品甲', '品监', '品罪', '品药', '商银', '因成', '国工', '国银', '型轿', '基苯', '处费', '大队', '失价', '头渔', '头部', '好处', '威胁', '客户', '害人', '害身', '家中', '容留', '射钉', '小包', '小型', '尸体', '局交', '局认', '属轻', '属醉', '工商', '工程', '己有', '币.', '币元', '年年', '并罚', '度轻', '开设', '式吸', '式赌', '张信', '张卡', '强行', '归还', '形式', '微伤', '恶意', '意伤', '意透', '戏机', '成分', '截止', '房间', '所得', '所民', '手机', '扑克', '打伤', '执勤', '执法', '执行', '批准', '承担', '投注', '抢劫', '抢夺', '抢救', '抢走', '抵押', '抽头', '担事', '担任', '拆迁', '持有', '损伤', '损毁', '掩饰', '支本', '支消', '支火', '支管', '支罪', '支行', '收取', '收受', '收购', '收超', '放在', '政府', '故发', '故意', '故认', '故责', '效死', '救无', '数罪', '数量', '方米', '无故', '无效', '时执', '明知', '晶体', '暴力', '月未', '有枪', '有毒', '有限', '木材', '木蓄', '木采', '未办', '未归', '未经', '本金', '机动', '构事', '林业', '林公', '林木', '枪一', '枪支', '某吸', '某容', '某血', '某负', '某贩', '某酒', '某驾', '某龙', '查获', '格认', '格贩', '检出', '检测', '检验', '森林', '欠款', '次容', '止年', '死亡', '殴打', '段时', '毁坏', '毒人', '毒品', '毒工', '毒年', '毒资', '民币', '民政', '民警', '汇款', '法医', '法执', '法持', '法收', '法获', '法贩', '洛因', '活动', '派出', '浓度', '海洛', '消费', '液中', '渔利', '游戏', '滥伐', '濮阳', '火药', '烫吸', '片剂', '猎枪', '现金', '玻璃', '理局', '理林', '琐事', '生争', '生产', '生口', '用卡', '用担', '用职', '甲基', '申请', '申领', '电脑', '留吸', '疑似', '疑物', '白色', '的虚', '监督', '盗窃', '盗走', '相撞', '真相', '督管', '瞒犯', '瞒真', '砍伐', '砸坏', '租住', '租赁', '积.', '称量', '程度', '窃取', '窃得', '窃所', '立方', '立木', '签订', '粉末', '精含', '索要', '纠纷', '经理', '经营', '给予', '缴获', '罪并', '罪所', '罪追', '职务', '聚众', '肇事', '股份', '胶囊', '胺冰', '胺年', '胺成', '脑损', '自制', '色晶', '色粉', '苯丙', '药动', '药品', '药枪', '获利', '获毒', '营利', '蓄积', '虚假', '虚构', '血样', '血液', '行人', '行信', '行催', '行申', '行股', '行驶', '补偿', '补助', '补贴', '被害', '被盗', '警查', '警车', '认定', '许可', '设赌', '证情', '诈骗', '该卡', '该车', '谋取', '谎称', '负事', '财政', '财物', '责任', '货款', '贩卖', '购买', '赃物', '资金', '赌人', '赌博', '赌场', '赌资', '赔偿', '超过', '路交', '路段', '路由', '身上', '身体', '车价', '车系', '车行', '轮摩', '轻伤', '轻微', '轿车', '辱骂', '过三', '近亲', '还年', '还款', '送给', '透支', '通事', '逾期', '道路', '配合', '酒后', '酒精', '酒驾', '醇含', '醇浓', '醉酒', '采伐', '重.', '重型', '量.', '金.', '钉枪', '银行', '销售', '长期', '间利', '队认', '阳性', '阻碍', '限公', '院抢', '随意', '隐瞒', '雇请', '非法', '面积', '面部', '项目', '颅脑', '额度', '食冰', '食品', '食毒', '食甲', '饮酒', '饰隐', '驶机', '驾驶', '骗取', '骗得', '骨折', '骨骨', '麻古', '麻将', '龙泉']
# train feature selected shape: (32171, 500)
# test feature selected shape: (3575, 500)
# -----------------------Logistic Regression-----------------------
# >>> training...
# train time cost: 208.6609 s
# >>> predicting...
# predict time cost: 0.195 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.90      0.95      0.93       367
#      信用卡..	       0.88      0.86      0.87        59
#      危险驾..	       0.98      0.98      0.98       768
#       受贿..	       0.84      0.75      0.79        28
#      合同诈..	       0.30      0.20      0.24        15
#      妨害公..	       0.96      0.66      0.78        41
#      容留他..	       0.96      0.92      0.94       154
#      寻衅滋..	       0.84      0.24      0.37        88
#      开设赌..	       0.66      0.73      0.69        26
#      引诱、..	       1.00      0.81      0.89        21
#       抢劫..	       0.91      0.45      0.60        65
#       抢夺..	       0.67      0.17      0.27        24
#      掩饰、..	       1.00      0.75      0.86        24
#      故意伤..	       0.90      0.96      0.93       467
#      故意杀..	       0.00      0.00      0.00        20
#      故意毁..	       0.67      0.24      0.35        17
#      敲诈勒..	       0.00      0.00      0.00        16
#      滥伐林..	       1.00      1.00      1.00        25
#      生产、..	       1.00      0.88      0.93        16
#       盗窃..	       0.90      0.98      0.94       759
#      组织、..	       1.00      0.81      0.89        21
#      职务侵..	       0.79      0.55      0.65        20
#       诈骗..	       0.92      0.60      0.73       122
#       贪污..	       0.45      0.60      0.51        15
#       赌博..	       0.89      0.68      0.77        25
#      走私、..	       0.92      0.95      0.94       300
#      过失致..	       1.00      0.05      0.10        19
#      非法拘..	       0.00      0.00      0.00        20
#      非法持..	       1.00      0.90      0.95        42
#      非法持..	       0.44      0.60      0.50        45
#
# avg / total       0.90      0.87      0.87      3629
#
# avg f1 score: 0.7691048165573269
# -----------------------SVM-----------------------
# >>> training...
# train time cost: 15283.3852 s
# >>> predicting...
# predict time cost: 219.9096 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.78      0.95      0.86       367
#      信用卡..	       0.91      0.85      0.88        59
#      危险驾..	       0.97      0.98      0.98       768
#       受贿..	       0.82      0.82      0.82        28
#      合同诈..	       0.56      0.60      0.58        15
#      妨害公..	       0.81      0.85      0.83        41
#      容留他..	       0.91      0.97      0.94       154
#      寻衅滋..	       0.83      0.33      0.47        88
#      开设赌..	       0.69      0.85      0.76        26
#      引诱、..	       1.00      1.00      1.00        21
#       抢劫..	       0.82      0.69      0.75        65
#       抢夺..	       0.83      0.62      0.71        24
#      掩饰、..	       0.79      0.96      0.87        24
#      故意伤..	       0.85      0.96      0.90       467
#      故意杀..	       0.18      0.10      0.13        20
#      故意毁..	       0.67      0.71      0.69        17
#      敲诈勒..	       0.36      0.25      0.30        16
#      滥伐林..	       1.00      1.00      1.00        25
#      生产、..	       1.00      0.94      0.97        16
#       盗窃..	       0.84      0.97      0.90       759
#      组织、..	       1.00      1.00      1.00        21
#      职务侵..	       0.81      0.65      0.72        20
#       诈骗..	       0.86      0.71      0.78       122
#       贪污..	       0.50      0.67      0.57        15
#       赌博..	       0.80      0.64      0.71        25
#      走私、..	       0.86      0.96      0.91       300
#      过失致..	       0.54      0.79      0.64        19
#      非法拘..	       0.53      0.45      0.49        20
#      非法持..	       0.95      0.95      0.95        42
#      非法持..	       0.57      0.73      0.64        45
#
# avg / total       0.85      0.91      0.88      3629
#
# avg f1 score: 0.8190204315438967
# -----------------------KNN-----------------------
# >>> training...
# train time cost: 371.3372 s
# >>> predicting...
# predict time cost: 685.4312 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.92      0.96      0.94       367
#      信用卡..	       0.82      0.93      0.87        59
#      危险驾..	       0.98      0.98      0.98       768
#       受贿..	       1.00      0.79      0.88        28
#      合同诈..	       0.57      0.53      0.55        15
#      妨害公..	       0.90      0.68      0.78        41
#      容留他..	       0.97      0.92      0.94       154
#      寻衅滋..	       0.64      0.31      0.42        88
#      开设赌..	       0.59      0.92      0.72        26
#      引诱、..	       1.00      0.95      0.98        21
#       抢劫..	       0.75      0.71      0.73        65
#       抢夺..	       0.67      0.50      0.57        24
#      掩饰、..	       0.90      0.79      0.84        24
#      故意伤..	       0.86      0.96      0.91       467
#      故意杀..	       0.38      0.40      0.39        20
#      故意毁..	       0.46      0.65      0.54        17
#      敲诈勒..	       0.27      0.38      0.32        16
#      滥伐林..	       1.00      1.00      1.00        25
#      生产、..	       1.00      0.94      0.97        16
#       盗窃..	       0.81      0.99      0.89       759
#      组织、..	       1.00      0.95      0.98        21
#      职务侵..	       0.65      0.75      0.70        20
#       诈骗..	       0.89      0.63      0.74       122
#       贪污..	       0.46      0.73      0.56        15
#       赌博..	       0.65      0.80      0.71        25
#      走私、..	       0.88      0.97      0.92       300
#      过失致..	       0.52      0.74      0.61        19
#      非法拘..	       0.64      0.35      0.45        20
#      非法持..	       1.00      0.90      0.95        42
#      非法持..	       0.47      0.78      0.58        45
#
# avg / total       0.86      0.91      0.88      3629
#
# avg f1 score: 0.8141531004983312
# -----------------------NN-----------------------
# >>> training...
# train time cost: 34.412 s
# >>> predicting...
# predict time cost: 2.6151 s
# >>> evaluating...
#              precision    recall  f1-score   support
#
#      交通肇..	       0.35      0.98      0.52       367
#      信用卡..	       0.16      0.92      0.28        59
#      危险驾..	       0.57      0.99      0.73       768
#       受贿..	       0.17      0.82      0.28        28
#      合同诈..	       0.03      0.80      0.06        15
#      妨害公..	       0.03      0.88      0.05        41
#      容留他..	       0.38      0.98      0.55       154
#      寻衅滋..	       0.07      0.88      0.13        88
#      开设赌..	       0.16      0.92      0.28        26
#      引诱、..	       0.24      0.90      0.38        21
#       抢劫..	       0.05      0.95      0.10        65
#       抢夺..	       0.06      0.83      0.11        24
#      掩饰、..	       0.03      0.96      0.06        24
#      故意伤..	       0.64      0.99      0.77       467
#      故意杀..	       0.04      0.75      0.07        20
#      故意毁..	       0.03      0.71      0.05        17
#      敲诈勒..	       0.02      0.75      0.04        16
#      滥伐林..	       0.28      0.96      0.43        25
#      生产、..	       0.19      0.75      0.31        16
#       盗窃..	       0.83      0.98      0.90       759
#      组织、..	       0.24      0.90      0.38        21
#      职务侵..	       0.03      0.80      0.06        20
#       诈骗..	       0.13      0.96      0.23       122
#       贪污..	       0.18      0.60      0.28        15
#       赌博..	       0.31      0.92      0.46        25
#      走私、..	       0.61      0.98      0.75       300
#      过失致..	       0.03      0.95      0.06        19
#      非法拘..	       0.03      0.75      0.06        20
#      非法持..	       0.08      0.90      0.14        42
#      非法持..	       0.09      0.84      0.15        45
#
# avg / total       0.50      0.96      0.62      3629
#
# avg f1 score: 0.32101171069513396
# -----------------------Decision Tree-----------------------
# >>> training...
# train time cost: 24.8984 s
# >>> predicting...
# predict time cost: 0.299 s
# >>> evaluating...
#              precision    recall  f1-score   support
